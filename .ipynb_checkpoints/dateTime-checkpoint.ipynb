# %%
import datetime
from dateutil.relativedelta import relativedelta

print(today)
# Out:
# 2021-12-24

# %%
def revenueRelease():
    if today.day>15:
        return today.replace(day=15)
    else:
        today.replace(month=today.month-1)
        return today.replace(day=15)

# %%
def monthsBefore(n):
    return (datetime.datetime.now()- relativedelta(months=n)).strftime("%Y-%m-%d")

# %%
def yearsBefore(n):
    return (datetime.datetime.now()- relativedelta(years=n)).strftime("%Y-%m-%d")

# %%
def monthsBefore(n):
    return (revenueRelease()- relativedelta(months=n)).strftime("%Y-%m-%d")

# %%
print(monthsBefore(5))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27796/253433390.py in <module>
# ----> 1 print(monthsBefore(5))
#
# ~\AppData\Local\Temp/ipykernel_27796/3896880295.py in monthsBefore(n)
#       1 def monthsBefore(n):
# ----> 2     return (revenueRelease()- relativedelta(months=n)).strftime("%Y-%m-%d")
#
# ~\AppData\Local\Temp/ipykernel_27796/2043764997.py in revenueRelease()
#       1 def revenueRelease():
# ----> 2     if today.day>15:
#       3         return today.replace(day=15)
#       4     else:
#       5         today.replace(month=today.month-1)
#
# AttributeError: 'str' object has no attribute 'day'

# %%
print(monthsBefore(11))
# Out:
# origin today 2022-05-23
# month 11
# year 0
# month 11
# today replace year 2022-05-23
# 2022-06-23

# %%
print(5//12)
# Out:
# 0

# %%
import datetime
from dateutil.relativedelta import relativedelta

# 减去一月
print((datetime.datetime.now()- relativedelta(months=1)).strftime("%Y-%m-%d"))
# Out:
# 2022-04-24

# %%
print(datetime.datetime.now()==datetime.datetime.today())
# Out:
# False

# %%
print((datetime.datetime.now()- relativedelta(months=1)))
print(datetime.datetime.today())
# Out:
# 2022-04-24 15:25:21.498521
# 2022-05-24 15:25:21.498521
