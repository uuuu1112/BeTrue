# %% [markdown]
# 最新四季的盈餘
# 上年同期盈餘
# 今年營收
# 上年營收
#
# 盈餘年增率
# 營收年增率
#
# 以現在的營收評估成長的機率

# %% [markdown]
# 評估一間公司最新的盈餘(最新的4季)
# 1.最新的3季 + 最新的3個月 * 最新的淨利率
# 2.最新的3季 + 最新的3個月 * 預估的淨利率
#
# 評估淨利率說明:
# 用回歸分析的方式預測
#
# 引用 1. or 2. ?
# 根據過去的經驗，看對各股來說，要用哪種評估方式

# %%
import requests
import pandas as pd
token="eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJkYXRlIjoiMjAyMi0wNS0yNCAxNDoyMjo1NyIsInVzZXJfaWQiOiJ1dXV1MTExMiIsImlwIjoiNjAuMjQ5LjE4MC4yMDAifQ.qQdzvWhSPBs5qttIge-e2fF9nkkj3r38owgwpKht4m8"
url = "https://api.finmindtrade.com/api/v4/data"
parameter = {
    "dataset": "TaiwanStockFinancialStatements",
    "start_date": "2019-03-31",
    "token": token}
data = requests.get(url, params=parameter)
data = data.json()
data = pd.DataFrame(data['data'])
print(data)
# Out:
#              date stock_id                                 type         value  \
# 0      2019-03-31   000116                                  EPS  2.400000e-01
# 1      2019-03-31   000116   EquityAttributableToOwnersOfParent  4.655690e+08
# 2      2019-03-31   000116                              Expense  8.954980e+08
# 3      2019-03-31   000116                               Income  1.077910e+09
# 4      2019-03-31   000116                     IncomeAfterTaxes  2.743220e+08
# ...           ...      ...                                  ...           ...
# 27282  2019-03-31     9960  TotalConsolidatedProfitForThePeriod  1.534400e+07
# 27283  2019-03-31     9960    TotalNonoperatingIncomeAndExpense  5.408000e+06
# 27284  2019-03-31     9962                      CostOfGoodsSold  5.369030e+08
# 27285  2019-03-31     9962                                  EPS -1.400000e-01
# 27286  2019-03-31     9962                          GrossProfit  2.721000e+06
#
#           origin_name
# 0           基本每股盈餘（元）
# 1      綜合損益總額歸屬於母公司業主
# 2               支出及費用
# 3                  收益
# 4            本期淨利（淨損）
# ...               ...
# 27282        本期綜合損益總額
# 27283        營業外收入及支出
# 27284            營業成本
# 27285       基本每股盈餘（元）
# 27286        營業毛利（毛損）
#
# [27287 rows x 5 columns]

# %%
filter=data["type"]=="EPS"

# print(filter)
print(data[filter])
# Out:
#              date stock_id type  value origin_name
# 0      2019-03-31   000116  EPS   0.24   基本每股盈餘（元）
# 16     2019-03-31   000538  EPS   0.09   基本每股盈餘（元）
# 31     2019-03-31   000616  EPS   0.17   基本每股盈餘（元）
# 46     2019-03-31   000700  EPS   0.11   基本每股盈餘（元）
# 61     2019-03-31   000779  EPS   0.24   基本每股盈餘（元）
# ...           ...      ...  ...    ...         ...
# 27233  2019-03-31     9951  EPS   1.94   基本每股盈餘（元）
# 27249  2019-03-31     9955  EPS   0.05   基本每股盈餘（元）
# 27266  2019-03-31     9958  EPS   0.07   基本每股盈餘（元）
# 27269  2019-03-31     9960  EPS   0.22   基本每股盈餘（元）
# 27285  2019-03-31     9962  EPS  -0.14   基本每股盈餘（元）
#
# [1640 rows x 5 columns]
