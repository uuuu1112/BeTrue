# %% [markdown]
# 最新四季的盈餘
# 上年同期盈餘
# 今年營收
# 上年營收
#
# 盈餘年增率
# 營收年增率
#
# 以現在的營收評估成長的機率

# %% [markdown]
# 評估一間公司最新的盈餘(最新的4季)
# 1.最新的3季 + 最新的3個月 * 最新的淨利率
# 2.最新的3季 + 最新的3個月 * 預估的淨利率
#
# 評估淨利率說明:
# 用回歸分析的方式預測
#
# 引用 1. or 2. ?
# 根據過去的經驗，看對各股來說，要用哪種評估方式
