# %%
from modules import Datetime 

test2=Datetime.RevenueDate()
print(test2.revenueRelease())
# Out:
# 2022-05-15

# %%
print(test2.revenue12Release())
# Out:
# ['2022-05-15', '2022-04-15', '2022-03-15', '2022-02-15', '2022-01-15', '2021-12-15', '2021-11-15', '2021-10-15', '2021-09-15', '2021-08-15', '2021-07-15', '2021-06-15']

# %%
test3=Datetime.EarnDate()
print(test3.earningReleaseDate())
# Out:
# ['2021-8-14', '2021-11-14', '2022-3-31', '2022-5-15']

# %%
print(test3.nYearRelease(3,test3.earningReleaseDate()))
# Out:
# ['2021-08-14', '2021-11-14', '2022-03-31', '2022-05-15', '2020-08-14', '2020-11-14', '2021-03-31', '2021-05-15', '2019-08-14', '2019-11-14', '2020-03-31', '2020-05-15']

# %%
import requests
import pandas as pd
url = "https://api.finmindtrade.com/api/v4/data"
parameter = {
    "dataset": "TaiwanStockFinancialStatements",
    "data_id": "2330",
    "start_date": "2019-01-01",
    "token": "", # 參考登入，獲取金鑰
}
data = requests.get(url, params=parameter)
data = data.json()
data = pd.DataFrame(data['data'])
print(data.head())
# Out:
#          date stock_id                                type         value  \
# 0  2019-03-31     2330                     CostOfGoodsSold  1.283520e+11
# 1  2019-03-31     2330                                 EPS  2.370000e+00
# 2  2019-03-31     2330  EquityAttributableToOwnersOfParent  6.600980e+10
# 3  2019-03-31     2330                         GrossProfit  9.035760e+10
# 4  2019-03-31     2330                    IncomeAfterTaxes  6.138730e+10
#
#       origin_name
# 0            營業成本
# 1       基本每股盈餘（元）
# 2  綜合損益總額歸屬於母公司業主
# 3      營業毛利（毛損）淨額
# 4        本期淨利（淨損）

# %%
pd.set_option('display.max_rows',None)
print(data)
# Out:
#            date stock_id                                 type         value  \
# 0    2019-03-31     2330                      CostOfGoodsSold  1.283520e+11
# 1    2019-03-31     2330                                  EPS  2.370000e+00
# 2    2019-03-31     2330   EquityAttributableToOwnersOfParent  6.600980e+10
# 3    2019-03-31     2330                          GrossProfit  9.035760e+10
# 4    2019-03-31     2330                     IncomeAfterTaxes  6.138730e+10
# 5    2019-03-31     2330                IncomeBeforeIncomeTax  6.818170e+10
# 6    2019-03-31     2330       IncomeFromContinuingOperations  6.138730e+10
# 7    2019-03-31     2330                            NetIncome  6.138730e+10
# 8    2019-03-31     2330              NoncontrollingInterests -6.523000e+06
# 9    2019-03-31     2330                    OperatingExpenses  2.601800e+10
# 10   2019-03-31     2330                      OperatingIncome  6.426600e+10
# ...
