# %%
from modules import earnManage

# %%
dateManage=earnManage.DateMange()
print(dateManage.nYearDate(2,'2022-9-1'))
# Out:
# ['2021-09-30', '2021-12-31', '2022-03-31', '2022-06-30', '2020-09-30', '2020-12-31', '2021-03-31', '2021-06-30']

# %%
getInfo=earnManage.getInfo()
print(getInfo.nYearData())
